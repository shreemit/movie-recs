# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
tmdb_5000_movies = pd.read_csv('../tmdb_5000_movies.csv')
tmdb_5000_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
tmdb_5000_movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
tmdb_5000_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
tmdb_5000_movies.drop(['homepage', 'tagline'], axis=1, inplace=True)

# %%
tmdb_5000_movies.dropna(inplace=True)

# %%
tmdb_5000_movies.duplicated().sum()
# Out:
# 0

# %%
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel

# Load pre-trained transformer model and tokenizer
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Example movie dataset
movies = [
    "Star Wars: A New Hope is a classic space opera film directed by George Lucas.",
    "Happy new year is a Bollywood movie directed by Farah Khan.",
    "The Lord of the Rings is a fantasy film directed by Peter Jackson.",
    "The Godfather is a crime film directed by Francis Ford Coppola.",
    "Inception is a science fiction action film directed by Christopher Nolan.",
    "The Shawshank Redemption is a drama film directed by Frank Darabont.",
    "Pulp Fiction is a black comedy crime film directed by Quentin Tarantino."
]

# Preprocess and encode the movie dataset
encoded_movies = []
for movie in movies:
    encoded_input = tokenizer(movie, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        output = model(**encoded_input)
    embeddings = output.last_hidden_state.mean(dim=1).squeeze().numpy()  # Mean pooling
    encoded_movies.append(embeddings)

# Function to perform semantic search
def semantic_search(query, encoded_docs, top_n=3):
    encoded_query = tokenizer(query, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        output = model(**encoded_query)
    query_embedding = output.last_hidden_state.mean(dim=1).squeeze().numpy()  # Mean pooling

    # Calculate cosine similarity between query and documents
    similarities = []
    for doc_embedding in encoded_docs:
        cosine_sim = np.dot(query_embedding, doc_embedding) / (np.linalg.norm(query_embedding) * np.linalg.norm(doc_embedding))
        similarities.append(cosine_sim)

    # Get indices of top similar documents
    top_indices = np.argsort(similarities)[::-1][:top_n]
    top_results = [(movies[i], similarities[i]) for i in top_indices]
    return top_results

# Example query
query = "What are some dark movies?"

# Perform semantic search
results = semantic_search(query, encoded_movies)
for movie, similarity in results:
    print(f"Movie: {movie}, Similarity: {similarity}")
# Out:
# Movie: Pulp Fiction is a black comedy crime film directed by Quentin Tarantino., Similarity: 0.6811084151268005
# Movie: Happy new year is a Bollywood movie directed by Farah Khan., Similarity: 0.6731266379356384
# Movie: Star Wars: A New Hope is a classic space opera film directed by George Lucas., Similarity: 0.6652545928955078

# %%
df = pd.read_csv('../movies2.csv.gz')
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv('../movies2.csv.gz')
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...
